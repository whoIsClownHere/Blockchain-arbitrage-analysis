# %% [markdown]
# # Общая аналитика блокчейн-арбитража

# %% [markdown]
# ## Библиотеки

# %%
import pandas as pd
# import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# ## Открытие данных

# %%
names = ['spread', 'start_buy_price', 'start_sell_price', 'end_buy_price', 'end_sell_price', 'start_time', 'end_time', 'ticker', 'buy_exchange', 'sell_exchange']
data = pd.read_csv('Datasets/arbitrage_data.tsv', names=names)

data['start_time'] = data['start_time'].apply(lambda x: datetime.fromtimestamp(x))
data['end_time'] = data['end_time'].apply(lambda x: datetime.fromtimestamp(x))
data['total_time'] = data['end_time'] - data['start_time']
data.head()
# Out:
#    spread  start_buy_price  start_sell_price  end_buy_price  end_sell_price  \
# 0  42.334          0.02975           0.05100        0.02268         0.02276
# 1   1.500          0.02266           0.02300        0.02262         0.02275
# 2   2.080          0.02263           0.02310        0.02263         0.02270
# 3   1.190          0.02263           0.02290        0.02263         0.02280
# 4   1.433          0.02281           0.02309        0.02294         0.02309
#
#            start_time            end_time    ticker buy_exchange  \
# 0 2022-11-01 00:00:00 2022-11-23 04:01:00  MDT/USDT      binance
# 1 2022-11-23 04:07:00 2022-11-23 04:07:00  MDT/USDT      binance
# 2 2022-11-23 04:13:00 2022-11-23 04:13:00  MDT/USDT      binance
# 3 2022-11-23 04:16:00 2022-11-23 04:16:00  MDT/USDT      binance
# 4 2022-11-23 07:04:00 2022-11-23 07:11:00  MDT/USDT      binance
#
#   sell_exchange       total_time
# 0          mexc 22 days 04:01:00
# 1          mexc  0 days 00:00:00
# 2          mexc  0 days 00:00:00
# 3          mexc  0 days 00:00:00
# 4          mexc  0 days 00:07:00

# %% [markdown]
# ## Общии графики

# %% [markdown]
# ### Среднее время

# %%
print(data['total_time'].mean())
# Out:
# 0 days 00:23:45.472263269

# %% [markdown]
# ### Средний spread

# %%
print(data['spread'].mean())
# Out:
# 2.450480649161667

# %% [markdown]
# ### Spread и время начала арбитража

# %%
data.plot.scatter(x='start_time', y='spread', figsize=(20, 10))
# Out:
# <AxesSubplot: xlabel='start_time', ylabel='spread'>

# %%
data.loc[data['spread'] <= 10].plot.scatter(x='start_time', y='spread', figsize=(20, 10))
# Out:
# <AxesSubplot: xlabel='start_time', ylabel='spread'>

# %% [markdown]
# ## Анализ spread

# %% [markdown]
# ### Проверка на сход цены

# %%
data['end_price_difference'] = data['end_buy_price'] - data['end_sell_price']
data.plot.scatter(x='start_time', y='end_price_difference', figsize=(20, 10))
# Out:
# <AxesSubplot: xlabel='start_time', ylabel='end_price_difference'>

# %%
sns.set_style("darkgrid")
sns.lineplot(data=data.loc[data['total_time'] <= 28800], x="total_time", y="spread")

# %%
data['quote'] = data['ticker'].apply(lambda x: x.split('/')[1])
values = data.groupby('quote')['spread'].count()
values.plot.bar(x='quote', y='spread')
# Out:
# <AxesSubplot: xlabel='quote'>

# %%
values = data.groupby('quote').apply(lambda x: x['spread'].mean())
values.plot.bar(x='quote', y='spread')
# Out:
# <AxesSubplot: xlabel='quote'>

# %% [markdown]
# ## Анализ бирж

# %% [markdown]
# ### Где чаще всего покупают

# %%
count_buy_exchanges = data.groupby('buy_exchange').apply(lambda x: x['spread'].count())
count_buy_exchanges.plot.bar(figsize=(15, 5))
# Out:
# <AxesSubplot: xlabel='buy_exchange'>

# %% [markdown]
# ### Где чаще всего продают

# %%
count_sell_exchanges = data.groupby('sell_exchange').apply(lambda x: x['spread'].count())
count_sell_exchanges.plot.bar(figsize=(15, 5))
# Out:
# <AxesSubplot: xlabel='sell_exchange'>

# %% [markdown]
# ### Средний spread у бирж где покупают

# %%
mean_buy_exchanges = data.loc[data['spread'] <= 50].groupby('buy_exchange').apply(lambda x: x['spread'].mean())
mean_buy_exchanges.plot.bar(figsize=(15, 5))
# Out:
# <AxesSubplot: xlabel='buy_exchange'>

# %% [markdown]
# ### Средний spread у бирж где продают

# %%
mean_sell_exchanges = data.groupby('sell_exchange').apply(lambda x: x['spread'].mean())
mean_sell_exchanges.plot.bar(figsize=(15, 5))
# Out:
# <AxesSubplot: xlabel='sell_exchange'>

# %% [markdown]
# ## Новая стратегия

# %%
data.head()
data['buy_price_differnce'] = data['end_buy_price'] - data['start_buy_price']
data['sell_price_differnce'] = data['start_sell_price'] - data['end_sell_price']

# %%
data['bad_for_strategy'] = data['buy_price_differnce'].apply(lambda x: x <= 0)

# %%
data.loc[data['total_time'] > pd.Timedelta(1, "minutes")].loc[]['spread'].count()
# Out:
# 318094

# %%
data.loc[data['total_time'] > pd.Timedelta(1, "minutes")].loc[data['sell_price_differnce'] > 0]['spread'].count()
# Out:
# 335168

# %%
data['bad_color'] = data.apply(lambda x: 'red' if x['bad_for_strategy'] == True else \
                               'blue', axis=1)

# %%
plt.figure(figsize=(20, 10))
plt.scatter(data["start_time"], data['buy_price_differnce'], color=data['bad_color'])
plt.legend(['Невыгодные для стратегии сделки'])

# %%
data.plot.scatter(x='start_time', y='sell_price_differnce', figsize=(20, 10))
# Out:
# <AxesSubplot: xlabel='start_time', ylabel='sell_price_differnce'>
